# %%
import math
import numpy as np
from pyscf import gto, scf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
LiH = gto.M(atom='H 0 0 0; Li 0 0 1.4', basis='sto-3g',unit='au',charge=0)
rhf = scf.RHF(LiH)
#print(LiH.nao)
e_rhf_sto3g = rhf.kernel()

LiH = gto.M(atom='H 0 0 0; Li 0 0 1.4', basis='ccpvdz',unit='au',charge=0)
rhf = scf.RHF(LiH)
#print(LiH.nao)
e_rhf_ccpvdz = rhf.kernel()

LiH = gto.M(atom='H 0 0 0; Li 0 0 1.4', basis='ccpvtz',unit='au',charge=0)
rhf = scf.RHF(LiH)
#print(LiH.nao)
e_rhf_ccpvtz = rhf.kernel()

LiH = gto.M(atom='H 0 0 0; Li 0 0 1.4', basis='ccpvqz',unit='au',charge=0)
rhf = scf.RHF(LiH)
#print(LiH.nao)
e_rhf_ccpvqz = rhf.kernel()
# Out:
# converged SCF energy = -7.54470387022927
# converged SCF energy = -7.6654526946354
# converged SCF energy = -7.67810974407451
# converged SCF energy = -7.67961681750832

# %%
ofile = open("pec.dat","w")
ofile.write("#r[au] Energy[a.u]\n")
for i in range(1,30):
    z = 0.4+0.2*i
    print(f"#Distance between LiH:{z:.3f}")
    
    LiH = gto.M(atom='H 0 0 0; Li 0 0 '+str(z), basis='sto-3g', unit='au',charge=0)
    rhf = scf.RHF(LiH)
    e_rhf_sto3g = rhf.kernel()
    
    LiH = gto.M(atom='H 0 0 0; Li 0 0 '+str(z), basis='ccpvdz', unit='au',charge=0)
    rhf = scf.RHF(LiH)
    e_rhf_ccpvdz = rhf.kernel()
    
    LiH = gto.M(atom='H 0 0 0; Li 0 0 '+str(z), basis='ccpvtz', unit='au',charge=0)
    rhf = scf.RHF(LiH)
    e_rhf_ccpvtz = rhf.kernel()
    
    LiH = gto.M(atom='H 0 0 0; Li 0 0 '+str(z), basis='ccpvqz', unit='au',charge=0)
    rhf = scf.RHF(LiH)
    e_rhf_ccpvqz = rhf.kernel()
    
    ofile.write("{0:.10f}\t{1:15.10f}{2:15.10f}{3:15.10f}{4:15.10f}\n"
                .format(z,e_rhf_sto3g,e_rhf_ccpvdz,e_rhf_ccpvtz,e_rhf_ccpvqz))
ofile.close()
# Out:
# #Distance between LiH:0.600
# converged SCF energy = -6.02157244857365
# converged SCF energy = -6.17661928274375
# converged SCF energy = -6.27720299215806
# converged SCF energy = -6.28896601245148
# #Distance between LiH:0.800
# converged SCF energy = -6.72747356247358
# converged SCF energy = -6.86317245379543
# converged SCF energy = -6.91517854045719
# converged SCF energy = -6.92267906618611
# #Distance between LiH:1.000
# converged SCF energy = -7.1188014236676
# converged SCF energy = -7.24864679535656
# converged SCF energy = -7.27990049136953
# converged SCF energy = -7.28388647209382
# #Distance between LiH:1.200
# converged SCF energy = -7.37263783011162
# converged SCF energy = -7.49786235307209
# converged SCF energy = -7.51743409542527
# converged SCF energy = -7.51960685319008
# #Distance between LiH:1.400
# converged SCF energy = -7.54470387022927
# converged SCF energy = -7.6654526946354
# converged SCF energy = -7.67810974407451
# converged SCF energy = -7.67961681750832
# #Distance between LiH:1.600
# converged SCF energy = -7.66194676645199
# converged SCF energy = -7.77909280593791
# converged SCF energy = -7.78774052072001
# converged SCF energy = -7.78900718603906
# #Distance between LiH:1.800
# converged SCF energy = -7.74106569060784
# converged SCF energy = -7.85579115398299
# converged SCF energy = -7.86219126835884
# converged SCF energy = -7.86332731575688
# #Distance between LiH:2.000
# converged SCF energy = -7.7935542327877
# converged SCF energy = -7.90695491974575
# converged SCF energy = -7.91212932678544
# converged SCF energy = -7.91315431195187
# #Distance between LiH:2.200
# converged SCF energy = -7.82737984641796
# converged SCF energy = -7.94044475551611
# converged SCF energy = -7.94492472067333
# converged SCF energy = -7.94584106488099
# #Distance between LiH:2.400
# converged SCF energy = -7.84797848019528
# converged SCF energy = -7.96167847763938
# converged SCF energy = -7.96570198752404
# converged SCF energy = -7.96651213390107
# #Distance between LiH:2.600
# converged SCF energy = -7.8590591475496
# converged SCF energy = -7.97437168214199
# converged SCF energy = -7.97803232341574
# converged SCF energy = -7.9787425541953
# #Distance between LiH:2.800
# converged SCF energy = -7.86320119668109
# converged SCF energy = -7.98107627440297
# converged SCF energy = -7.9844131558809
# converged SCF energy = -7.98503472230905
# #Distance between LiH:3.000
# converged SCF energy = -7.86224631041032
# converged SCF energy = -7.98356453475836
# converged SCF energy = -7.9866016497778
# converged SCF energy = -7.98715047811043
# #Distance between LiH:3.200
# converged SCF energy = -7.85754040672691
# converged SCF energy = -7.983083699169
# converged SCF energy = -7.98584476761831
# converged SCF energy = -7.98633947499274
# #Distance between LiH:3.400
# converged SCF energy = -7.85008329528038
# converged SCF energy = -7.98051976609199
# converged SCF energy = -7.98303519812097
# converged SCF energy = -7.98349460765891
# #Distance between LiH:3.600
# converged SCF energy = -7.8406254328416
# converged SCF energy = -7.97650693639429
# converged SCF energy = -7.97881562491833
# converged SCF energy = -7.97925572610596
# #Distance between LiH:3.800
# converged SCF energy = -7.82973402578066
# converged SCF energy = -7.97150273050095
# converged SCF energy = -7.97364966828256
# converged SCF energy = -7.97408100122885
# #Distance between LiH:4.000
# converged SCF energy = -7.81784041501294
# converged SCF energy = -7.96583963758549
# converged SCF energy = -7.96787200000504
# converged SCF energy = -7.96830055794404
# #Distance between LiH:4.200
# converged SCF energy = -7.80527531447719
# converged SCF energy = -7.95976066249684
# converged SCF energy = -7.96172444783293
# converged SCF energy = -7.96215425708978
# #Distance between LiH:4.400
# converged SCF energy = -7.79229562714197
# converged SCF energy = -7.95344397956919
# converged SCF energy = -7.95538185602917
# converged SCF energy = -7.9558166351204
# #Distance between LiH:4.600
# converged SCF energy = -7.77910492237929
# converged SCF energy = -7.94702023133895
# converged SCF energy = -7.94897043104214
# converged SCF energy = -7.94941422556566
# #Distance between LiH:4.800
# converged SCF energy = -7.76586872057956
# converged SCF energy = -7.94058482549409
# converged SCF energy = -7.94258078423344
# converged SCF energy = -7.94303813464322
# #Distance between LiH:5.000
# converged SCF energy = -7.75272529534887
# converged SCF energy = -7.93420680563825
# converged SCF energy = -7.93627731978632
# converged SCF energy = -7.93675328132731
# #Distance between LiH:5.200
# converged SCF energy = -7.73979262352748
# converged SCF energy = -7.92793536484185
# converged SCF energy = -7.93010508294863
# converged SCF energy = -7.93060520741197
# #Distance between LiH:5.400
# converged SCF energy = -7.72717222495445
# converged SCF energy = -7.92180472595638
# converged SCF energy = -7.92409480300111
# converged SCF energy = -7.92462510159801
# #Distance between LiH:5.600
# converged SCF energy = -7.71495077353407
# converged SCF energy = -7.91583786834662
# converged SCF energy = -7.9182666333605
# converged SCF energy = -7.91883350798903
# #Distance between LiH:5.800
# converged SCF energy = -7.70320040671123
# converged SCF energy = -7.91004941010508
# converged SCF energy = -7.91263294653373
# converged SCF energy = -7.91324306969933
# #Distance between LiH:6.000
# converged SCF energy = -7.69197856191879
# converged SCF energy = -7.90444784360509
# converged SCF energy = -7.90720043632779
# converged SCF energy = -7.90786057029164
# #Distance between LiH:6.200
# converged SCF energy = -7.68132794869684
# converged SCF energy = -7.89903725682419
# converged SCF energy = -7.90197169799123
# converged SCF energy = -7.90268846797216

# %%
R,es,ed,et,eq = np.loadtxt("./pec.dat",unpack=True)
plt.figure(figsize=(7, 5))
plt.plot(R,es,label='sto-3g')
plt.plot(R,ed,label='cc-pvdz')
plt.plot(R,et,label='cc-pvtz')
plt.plot(R,eq,label='cc-pvqz')
plt.legend(loc='best')
plt.xlabel('bond length (au)')
plt.ylabel('total energy')
plt.ylim(-8.0, -7.6)
# Out:
# (-8.0, -7.6)
